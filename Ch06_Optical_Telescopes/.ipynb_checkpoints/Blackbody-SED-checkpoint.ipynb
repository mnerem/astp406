# %% [markdown]
# # Blackbody SED plots

# %%
import numpy as np
from scipy.constants import *
import plotly.express as px

# %%
def Rayleigh_Jeans(λ,T):
    # λ in nanomters
    return 8*pi*k*T/(λ*1e-9)**4

# %%
em_spectrum=np.arange(200,700) # visible band = [380,700], λ=200nm is UV
T=[300,500,1000,2000]

# %%
fig = px.line(x=em_spectrum,y=Rayleigh_Jeans(em_spectrum,0))
for tt in T:
    fig.add_scatter(x=em_spectrum,y=Rayleigh_Jeans(em_spectrum,tt))

# %%
fig.show()
